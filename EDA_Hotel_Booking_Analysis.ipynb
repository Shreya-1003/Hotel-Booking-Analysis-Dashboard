# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreya-1003/Hotel-Booking-Analysis-Dashboard/blob/main/EDA_Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name-Hotel Booking Analysis**

# %% [markdown]
# **Project Type-**EDA
#
# **Contribution-**Team
#
# **Team Member 1-**Poonam  khairnar
#
# **Team Member 2**-Shreya Thorat

# %% [markdown]
# #**Project Summary-**

# %% [markdown]
# In the hotel industry, understanding customer behavior and optimizing booking strategies is crucial for maximizing revenue and ensuring guest satisfaction. This project addresses several key business challenges:
#
# 1-Seasonal Booking Patterns: Hotels often experience fluctuations in occupancy rates due to seasonal variations. Identifying the best time of year to book a hotel room can help establishments plan their pricing and marketing strategies effectively.
#
# 2-Optimal Length of Stay: Determining the ideal duration for a guest's stay that offers the most cost-effective pricing is essential. This insight can help hotels optimize room utilization and revenue.
#
# 3-Special Requests: Meeting guest preferences and special requests is crucial for guest satisfaction. Predicting which bookings are likely to include special requests can help hotels allocate resources and staff effectively.
#
# 4-Revenue Management: Effective revenue management is a critical challenge in the hotel industry. By analyzing data, hotels can better forecast demand, optimize pricing strategies, and improve overall revenue.
#
# 5-Customer Experience: Providing a personalized and seamless guest experience is a key competitive advantage. Understanding customer booking behavior and preferences can enhance the guest experience and drive repeat business.
#
# Overall, the project aims to provide insights and recommendations that enable hotels to enhance their booking strategies, improve guest experiences, and ultimately drive revenue growth while maintaining customer loyalty in a dynamic and competitive industry.

# %% [markdown]
# ## **GitHub Link-**
#  https://github.com/Shreya-1003/CapStone-Projects-Module_2.git
#
#  https://github.com/Poonam-github3011/Capstone-Project_module2

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The hotel industry is highly dynamic, and understanding the factors that influence booking decisions is critical for hotels to maximize revenue and enhance guest satisfaction. We aim to explore a hotel booking dataset, which includes booking information for both a city hotel and a resort hotel. The objective is to perform an in-depth exploratory data analysis (EDA) to uncover important factors that govern hotel bookings

# %% [markdown]
# **Business Objective-**

# %% [markdown]
# To identify and leverage data-driven insights to optimize booking strategies, enhance revenue management, and improve guest experiences in order to increase overall hotel revenue and customer retention

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# # ***1.Know Your Data***

# %% [markdown]
# # Import Liabraries

# %%
#Import liabraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Dataset Loading

# %%
#Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Read csv file
hotel_df=pd.read_csv("/content/drive/MyDrive/Capstone-Project_Module2/Hotel Bookings.csv")

# %% [markdown]
# # Dataset First View

# %%
#Dataset First Look
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# This gives us the first look of dataset

# %% [markdown]
# # Dataset Rows & Column count

# %%
#Dataset Rows and Column count
hotel_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# In this cell we got to know that there are 119390 rows and 32 columns in the dataset

# %% [markdown]
# # Dataset Information

# %%
#Dataset Info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# The .info() function gives us the overal of summary of the dataset including datatype of each column and memory usage of the netire data

# %%
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# We  can see that there are 32 columns in the dataset and some columns like 'children', 'company', 'country' and 'agent' have null values.

# %% [markdown]
# # Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_values = hotel_df.duplicated().value_counts()
duplicate_values
# Out:
# False    87396
# True     31994
# dtype: int64

# %% [markdown]
# We can see that there are 31994 duplicate values in dataset

# %%
# Visualizing the duplicate values
plt.figure(figsize=(7,7))
sns.countplot(x=hotel_df.duplicated())
plt.title('Visualization of Duplicate Values', fontsize = 18)
plt.ylabel('Count of Duplicate Values', fontsize = 14)
plt.show()

# %%
# Drop Duplicate Values
hotel_df = hotel_df.drop_duplicates()
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# #Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = hotel_df.isnull().sum()

missing_values
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.heatmap(hotel_df.isnull(), cbar=False, cmap='viridis')  # Use 'viridis' colormap for better visibility
plt.title('Missing Values Heatmap')  # Add a title to the plot
plt.show()

# %% [markdown]
# **What did you know about your dataset?**
#
#
#
#
#
# In this dataset we have two hotels, H1= City hotel and H2= Resort hotel. In this data we compares various booking information between these two, information such as when the booking was canceled, customer arrival date, month & year, number of people stayed in hotel and how many of them are adults,childeren or babies and from where they came and what type of meal they opted for themselves,and it also shows that if any customer had booked hotel previously or canceled their booking previously and have other information also. In this dataset some values are duplicated which we also removed from this data & and make it more accurate. In this we got to know all the information about hotel booking of both the hotels

# %% [markdown]
# #***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotel_df.describe(include='all')
# Out:
#              hotel   is_canceled     lead_time  arrival_date_year  \
# count        87396  87396.000000  87396.000000       87396.000000
# unique           2           NaN           NaN                NaN
# top     City Hotel           NaN           NaN                NaN
# freq         53428           NaN           NaN                NaN
# mean           NaN      0.274898     79.891368        2016.210296
# std            NaN      0.446466     86.052325           0.686102
# min            NaN      0.000000      0.000000        2015.000000
# 25%            NaN      0.000000     11.000000        2016.000000
# 50%            NaN      0.000000     49.000000        2016.000000
# 75%            NaN      1.000000    125.000000        2017.000000
# max            NaN      1.000000    737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count               87396              87396.000000
# unique                 12                       NaN
# ...

# %% [markdown]
# ## Variables Description
#
# **- Hotel:** Type of hotel(City or Resort)
# is_cancelled: If the booking was cancelled(1) or not(0)
#
# **- lead_time:** Number of days before the actual arrival of the guests
#
# **- arrival_date_year:** Year of arrival date
#
# **- arrival_date_month:** Month of arrival date
#
# **- arrival_date_week_number:** Week number of year for arrival date
#
# **- arrival_date_day_of_month:** Day of arrival date
#
# **- stays_in_weekend_nights:** Number of weekend nights(Saturday or Sunday) spent at the hotel by the guests.
#
# **- stays_in_weel_nights:** Number of weeknights(Monday to Friday) spent at the hotel by the guests.
#
# **- adults:** Number of adults among the guests
#
# **- children:** Number of children
#
# **- babies:** Number of babies
#
# **- meal:** Type of meal booked
#
# **- country:** country of the guests
#
# **- market_segment:** Designation of market segment
#
# **- distribution_channel:** Name of booking distribution channel
#
# **- is_repeated_guest:** If the booking was from a repeated guest(1) or not(0)
#
# **- previous_cancellation:** Number of previous bookings that were cancelled by the customer prior to the current booking
#
# **- previous_bookings_not_cancelled:** Number of previous bookins not cancelled by the customer prior to the current bookin
#
# **- reserved_room_type:** Code from room type reserved
#
# **- assigned_room_type:** Code of room type assigned
#
# **- booking_changes:** Number of changes made to the booking
#
# **- deposit_type:** Type of deposite made by the guest
#
# **- agent:** ID of travel agent who made the booking
#
# **- comapny:** ID of the company that made the booking
#
# **- days_in_waiting_list:** Number of the days the booking was in the waiting list
#
# **- customer_type:** Type of customer, assuming one of four categories
#
# **- adr:** Average daily rate
#
# **- required_car_parking_spaces:** Number of car parking spaces required by the customer
#
# **- total_of_special_requesrs:** Number of special requests made by the customer
#
# **- reservation_statuse:** Reservation status(Canceled, check-out or no-show)
#
# **- reservation_status_date:** Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in hotel_df.columns.tolist():
  print("No. of unique values in ",i,"is",hotel_df[i].nunique(),".")
# Out:
# No. of unique values in  hotel is 2 .
# No. of unique values in  is_canceled is 2 .
# No. of unique values in  lead_time is 479 .
# No. of unique values in  arrival_date_year is 3 .
# No. of unique values in  arrival_date_month is 12 .
# No. of unique values in  arrival_date_week_number is 53 .
# No. of unique values in  arrival_date_day_of_month is 31 .
# No. of unique values in  stays_in_weekend_nights is 17 .
# No. of unique values in  stays_in_week_nights is 35 .
# No. of unique values in  adults is 14 .
# No. of unique values in  children is 5 .
# No. of unique values in  babies is 5 .
# No. of unique values in  meal is 5 .
# No. of unique values in  country is 177 .
# No. of unique values in  market_segment is 8 .
# No. of unique values in  distribution_channel is 5 .
# No. of unique values in  is_repeated_guest is 2 .
# No. of unique values in  previous_cancellations is 15 .
# No. of unique values in  previous_bookings_not_canceled is 73 .
# ...

# %% [markdown]
# # ***3. Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
hotel_df = hotel_df.drop_duplicates()
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#Replacing Null values
null_columns=['company','agent','children']
for columns in null_columns:
  hotel_df[columns].fillna(0,inplace=True)

#Replacing the NA values of country column with others
hotel_df['country'].fillna('others',inplace=True)

# %%
# Null values have been removed or filled
hotel_df.isnull().sum().reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                            Columns  Null values
# 0                            hotel            0
# 1                      is_canceled            0
# 2                        lead_time            0
# 3                arrival_date_year            0
# 4               arrival_date_month            0
# 5         arrival_date_week_number            0
# 6        arrival_date_day_of_month            0
# 7          stays_in_weekend_nights            0
# 8             stays_in_week_nights            0
# 9                           adults            0
# 10                        children            0
# 11                          babies            0
# 12                            meal            0
# 13                         country            0
# 14                  market_segment            0
# 15            distribution_channel            0
# 16               is_repeated_guest            0
# 17          previous_cancellations            0
# 18  previous_bookings_not_canceled            0
# ...

# %% [markdown]
# ### **Adding New Columns to the Dataset**

# %%
# Adding total number of people stayed in the hotels
hotel_df['total_people'] = hotel_df['adults'] + hotel_df['babies'] + hotel_df['children']

# Adding Total staying days in the hotels
hotel_df['total_stay'] = hotel_df['stays_in_weekend_nights'] + hotel_df['stays_in_week_nights']

# %%
#Changing the data type of total people column from float to int
hotel_df['total_people'] = hotel_df['total_people'].astype(int)

# %%
# Dataset view after adding the columns
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...      0.0
# ...

# %% [markdown]
# ### There are some rows in total number of adults, children or babies equal to zero this means no booking were made. So we can remove such rows.

# %%
# shape of columns which have no bookings
hotel_df[hotel_df['adults']+hotel_df['babies']+hotel_df['children'] == 0].shape
# Out:
# (166, 34)

# %%
# Columns are dropped here using drop function
hotel_df.drop(hotel_df[hotel_df['adults']+hotel_df['babies']+hotel_df['children'] == 0].index, inplace = True)

# %%
# All null values have been removed
hotel_df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# ## What all manipulations have you done and insights you found?
#
#
#
# **1.In the given dataframe, there were 31994 duplicate values. So those values were removed.**
#
# **2.There were 4 columns which have missing values and the columns were 'company','agent','country','children'. The values from these columns are replaced by zero and others.**
#
# **3.For better analysis,We have added two columns total_stay and total_people.**
#
# **4.Three columns 'adults','children','babies' have values zero which means no booking has done here, so these zero values were removed.**

# %% [markdown]
# # ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Univariate** **Analysis**

# %% [markdown]
# ### Chart - 1

# %% [markdown]
# ### 1. Which type of hotel is mostly preferred by the guests?

# %%
#chart-1 visualization code
hotel_counts = hotel_df['hotel'].value_counts()
hotel_counts
# Out:
# City Hotel      53428
# Resort Hotel    33968
# Name: hotel, dtype: int64

# %%
#piechart is used for visualization
hotel_counts.plot.pie(explode=[0.05, 0.05], autopct='%1.2f%%', shadow=True, figsize=(10,7),fontsize=15)
plt.title('Pie chart for most preferred Hotel',fontsize=15)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
#
#
# **I used the pie chart because it gives a simple and easy-to-understand analysis of the hotel type that has more bookings.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
#
# **The city hotel has more bookings, which means that its occupancy rate is 61.13%. The resort hotel has fewer bookings, which results in a lower occupancy rate of 38.87%.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# **Gaining insights helps create a positive business impact.**
#
# **City hotels can find more services to attract more guests to increase their revenue.**
#
# **Resort hotels can look into solutions to attract more guests, as well as looking into the facilities which can be provided by them to increase footfall.**

# %% [markdown]
# ### Chart - 2

# %% [markdown]
# ### 2. Which agent made the most bookings?

# %%
#chart-2 visualization code
highest_bookings = hotel_df.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings"}).sort_values(by='Most_Bookings',ascending=False)
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True)

# taking top 10 bookings made by agent
top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 8      9.0          28759
# 173  240.0          13028
# 13    14.0           3349
# 6      7.0           3300
# 182  250.0           2779
# 174  241.0           1644
# 26    28.0           1502
# 7      8.0           1383
# 0      1.0           1232
# 5      6.0           1117

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])
plt.title('Most bookings made by the agent', fontsize=15)
plt.ylabel('Number of bookings', fontsize=15)
plt.xlabel('Agent number', fontsize=15)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I choose barplot here because it provides a visual representation of the data, making it easy to compare.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **Agent No. 9 has made the most number of bookings.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#   **1.Yes, Agent no. 9 has made more bookings than his colleagues.This makes a positive impact on their business.**
#
#   **2.Agent 1 and 6 have fewer bookings, which makes a negative impact on the agency's ability to attract clients.**
#
#   **3.Bookings made by agents no 1 and 6 are about 4.27% of agents no 9's bookings which make up the highest percentage of bookings in the agency.**

# %% [markdown]
# ### Chart - 3

# %% [markdown]
# ### **3.What is the most preferred room type by the customers?**

# %%
#chart-3 visualization code
room_type = hotel_df['assigned_room_type'].value_counts()
room_type
# Out:
# A    46313
# D    22432
# E     7195
# F     3627
# G     2498
# C     2165
# B     1820
# H      706
# I      357
# K      276
# P        6
# L        1
# Name: assigned_room_type, dtype: int64

# %%
# Countlot is used for visualization of most preferred room type
plt.figure(figsize=(10,5))
sns.countplot(x=hotel_df['assigned_room_type'],order=hotel_df['assigned_room_type'].value_counts().index)
plt.title("Most preferred Room type", fontsize = 15)
plt.xlabel('Type of the Room', fontsize = 15)
plt.ylabel('Room type count', fontsize = 15)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I have chosen a count plot to visualize the most preferred room type because it displays the count of each observation for each category.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **The insight found from the chart is that type A rooms are the most preferred rooms while on the contrary Type L and K rooms are less preferred.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# **1.The A-type rooms are the most preferred, which has a positive impact on business.**
#
# **2.The H, I, K and L types of rooms are less preferred and have a negative effect on business.**

# %% [markdown]
# ### Chart - 4

# %% [markdown]
# ### **What is the percentage of cancellation?**

# %%
# Chart - 4 visualization code
hotel_df['is_canceled'].value_counts().plot.pie(explode=[0.05,0.05],autopct='%1.2f%%',shadow=True,figsize=(10,7),fontsize=20)
plt.title("Cancellation and non-cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and non-cancellation')

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I have used the pie chart for visualization because we have to make the decisions on the basis of comparisons and this chart is good when fewer variables need to be compared.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **Here:**
#
# **1 represents Not Cancelled**
#
# **So, from the visualization, we can conclude that 27.52% of bookings were cancelled and the remaining were not.**

# %% [markdown]
# **3.Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
#
#
# **Yes, the insights from the analysis have created a positive business impact because most of the bookings were not cancelled and it helped the business to generate revenue. They may use these findings to find the reasons that can be improved so that revenue can be increased.**

# %% [markdown]
# ### Chart - 5

# %% [markdown]
# 5.**What** is the percentage of repeated guests?

# %%
# Chart - 5 visualization code
repeated_guests_counts=hotel_df['is_repeated_guest'].value_counts()
repeated_guests_counts
# Out:
# 0    115580
# 1      3810
# Name: is_repeated_guest, dtype: int64

# %%
# Barplot is used for visaulization
repeated_guests_counts.plot.pie(explode=[0.03, 0.03], autopct='%1.2f%%', shadow=True, figsize=(10,7),fontsize=20)
plt.title('Percentage of repeated guests ',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Percentage of repeated guests ')

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I have used the pie chart for visualization because we have to make the decisions on the basis of comparisons and this chart is good when fewer variables need to be compared.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **There are very few guests who have booked the same hotel again.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# **Yes, the gained insights help create a positive business impact. The hotels which did not get booked by the guests repeatedly can take feedback from the guests and try to improve their services.**

# %% [markdown]
# ### Chart - 6

# %% [markdown]
# ### 6.**What type of food is mostly preferred by the guests?**

# %%
# Chart - 6 visualization code
preferred_food=hotel_df['meal'].value_counts()
preferred_food
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.countplot(x=hotel_df['meal'],order=hotel_df['meal'].value_counts().index)
plt.title("Most preferred Food",fontsize=20)
plt.xlabel('Type of the food',fontsize=15)
plt.ylabel('Food type count',fontsize=15)
# Out:
# Text(0, 0.5, 'Food type count')

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I have chosen to represent the most preferred food on a count plot because the count plot displays counts of each observation for each category and from this comparision beacomes easier.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# Types of meal in hotels:
#
# *  BB - (Bed and Breakfast)
#
# * HB- (Half Board)
#
# * FB- (Full Board)
#
# * SC- (Self Catering)
#
# **BB Food type is most preferred type while FB Food type is least preferred type.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
#  1. **BB food type is most preferred food and hence this makes a positive impact on the business.**
#
#  2. **Undefined and FB food types are less preferred and this makes a negative impact on the business.**
#
# 3. **HB nad SC Food types are equally preferred.**
#
# 4. **The BB food type is preferred by 67907 guests and FB food type is preferred by only 360 guests.**

# %% [markdown]
# ### Chart - 7

# %% [markdown]
# ### **7. Which year has the highest bookings?**

# %%
year_count = hotel_df['arrival_date_year'].value_counts().sort_index()
year_count
# Out:
# 2015    21996
# 2016    56707
# 2017    40687
# Name: arrival_date_year, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=year_count.index, y=year_count.values)
plt.title('Year wise Bookings', fontsize=20)
plt.xlabel('Arrival_date_year', fontsize=15)
plt.ylabel('Count of bookings', fontsize=15)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I have chosen to represent the highest bookings on a count plot because the count plot displays counts of each observation for each category and from this comparision beacomes easier.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **Year 2016 had the highest bookings and Year 2015 had the lowest bookings and Year 2017 had the average number of bookings.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 1. **Year 2016 had highest bookings this makes a positive impact.**
#
# 2. **Year 2015 had lowest bookings this makes a negative impact.**
#
# 3. **In 2016 there were 42313 bookings and In 2015 there were 13284 bookings.**

# %% [markdown]
# ### Chart - 8

# %% [markdown]
# ### **8.In which month most of the bookings happened?**

# %%
# Chart - 8 visualization code
bookings_by_months=hotel_df.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts of booking"}).sort_values('Counts of booking' , ascending = False)
bookings_by_months
# Out:
#    arrival_date_month  Counts of booking
# 1              August              13877
# 5                July              12661
# 8                 May              11791
# 10            October              11160
# 0               April              11089
# 6                June              10939
# 11          September              10508
# 7               March               9794
# 3            February               8068
# 9            November               6794
# 2            December               6780
# 4             January               5929

# %%
bookings_by_months=hotel_df.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts of booking"})
sequence_of_months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
bookings_by_months['arrival_date_month']=pd.Categorical(bookings_by_months['arrival_date_month'],categories=sequence_of_months,ordered=True)
bookings_by_months=bookings_by_months.sort_values('arrival_date_month')
bookings_by_months
# Out:
#    arrival_date_month  Counts of booking
# 4             January               5929
# 3            February               8068
# 7               March               9794
# 0               April              11089
# 8                 May              11791
# 6                June              10939
# 5                July              12661
# 1              August              13877
# 11          September              10508
# 10            October              11160
# 9            November               6794
# 2            December               6780

# %%
# Visualization of month in which most booking happened using Barplot.
plt.figure(figsize=(14,7))
sns.barplot(data=bookings_by_months, x="arrival_date_month", y="Counts of booking")
plt.title("Number of Bookings in Months", fontsize = 20)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Number of Bookings', fontsize = 15)
# Out:
# Text(0, 0.5, 'Number of Bookings')

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I choose barplot here because it provides data visualization in pictorial form, which makes comparison easier.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **August month has the maximum number of bookings and January has the lowest.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 1. **July and August months have the most bookings, this is a positive impact on business**
#
# 2. **November, December and January months have fewer bookings, this is a negative impact.**
#
# 3. **July and August months have above-average bookings while November, December and January months have below-average bookings.**

# %% [markdown]
# ### Chart - 9 - Histogram

# %%
# Chart - 9 visualization code
# Plotting histogram

hotel_df.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **To understand the data in a clear way with proper insights, I have used the histogram here. The histogram is a proper graphing tool, it is used to summarize discrete or continous data that are measured on a interval scale.** **it is often used to illustrate the major features of the distribution of the data in a convenient form.** **It is also used for dealing large data sets (greater than 100 observations). It can detect any unusal observations or any gaps in the data,** **Thus we have used the histogram plot to analyse the variable distributions over the whole dataset weather it's symmetric or not.**

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?
#
# Some insights found from the chart are as follows:-
#
#
# * **We can see that the maximum guest came in 2016.**
#
# * **Maximum arrival week number is 30.**
#
# * **Maximum arrival happens in the last of the month**
#
# * **Maximum guests comes with no children**
#
# * **There is less requirement of car parking spaces.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# **Just a histogram cannot define business impact. It's done just to see the distribution of the column data over the dataset.**

# %% [markdown]
# # **Bivariate and Multivariate analysis**

# %% [markdown]
# ## Chart - 10

# %% [markdown]
# 1.**Which hotel type has the highest ADR?**

# %%
# Chart - 10 visualization code
highest_adr = hotel_df.groupby('hotel')['adr'].mean().reset_index()
highest_adr
# Out:
#           hotel         adr
# 0    City Hotel  105.304465
# 1  Resort Hotel   94.952930

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
plt.title('Average ADR for each Hotel Type', fontsize=20)
plt.xlabel('Type of hotel',fontsize=15)
plt.ylabel('ADR',fontsize=15)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I choose barplot here because it provides data visualization in pictorial form, which makes comparison easier.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **City Hotel has the highest ADR which means they have generated the highest revenue for the business.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 1. **The hotel industry has high adr, making it a positive influence.**
#
#
# 2. **The resort hotel, however, has less adr as compared to the city hotel, which makes a negative impact.**
#
#
# 3. **The city hotel has adr 110.98 while the resort hotel has 99.02; this means that the resort hotel should look for solutions to improve their facilities which would increase their adr in future.**

# %% [markdown]
# ## Chart - 11

# %% [markdown]
# **2. Relationship between ADR and total number of people?**

# %%
number_of_people = hotel_df[hotel_df['total_people']<5]
number_of_people
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=number_of_people['total_people'],y= number_of_people['adr'])
plt.title('ADR and total number of people', fontsize=20)
plt.xlabel('Total people',fontsize=15)
plt.ylabel('adr', fontsize=15)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I choose barplot here because it provides data visualization in pictorial form, which makes comparison easier.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **ADR is positively increasing with the increase in the number of total people.**

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 1. **As the ADR is incresing with the number of total people, so this makes a positive impact on the business.**
#
# 2. **There are no insights that lead to negative growth.**

# %% [markdown]
# ### Chart - 12

# %% [markdown]
# ### 3.**Relationship between ADR and total stay.**

# %%
# Chart - 14 visualization code
adr_vs_stay = hotel_df.groupby(['total_stay', 'adr','hotel']).agg('count').reset_index().rename(columns={'is_canceled':'Number of stays'})
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay[:18000]
adr_vs_stay
# Out:
#        total_stay     adr         hotel
# 0               0    0.00    City Hotel
# 1               0    0.00  Resort Hotel
# 2               1    0.00    City Hotel
# 3               1    0.00  Resort Hotel
# 4               1    1.00    City Hotel
# ...           ...     ...           ...
# 17995           7  210.86  Resort Hotel
# 17996           7  211.00  Resort Hotel
# 17997           7  211.03  Resort Hotel
# 17998           7  211.16  Resort Hotel
# 17999           7  211.20  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
#plot line chart
plt.figure(figsize=(16,8))
sns.lineplot(x='total_stay',y='adr',data=adr_vs_stay)
plt.title('Relationship between adr and total stay', fontsize = 20)
plt.xlabel('total_stay',fontsize=15)
plt.ylabel('adr', fontsize=15)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?
#
# **I used the line plot because it gives the trend between the two variables and we can see the trend whether it is in decreasing or increasing trend.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
# **Total stay and adr are increasing positively.**

# %% [markdown]
# ### Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(20,10))
sns.heatmap(hotel_df.corr(),annot=True)
plt.title('Correlation of the columns')
plt.show()
# Out:
# <ipython-input-56-5b854f4c4972>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(hotel_df.corr(),annot=True)

# %% [markdown]
# 1. Why did you pick the specific chart?
#
# **Heatmaps are a visual way of representing various types of data. They show how a number of different variables relate to one another by assigning different colors and size to different elements.**

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?
#
#
# 1. **arrival_date_year and arrival_date_week_number columns have a negative correlation which is -0.51.**
#
#
# 2. **stays_in_week_nights and total_stay have a positive correlation which is 0.95.**
#
# 3. **The negative correlation between is_canceled and same_room_alloted_or_not holds true. That means a customer is unlikely to cancel his bookings if he doesn't get the same room as per reserved room. We have visualized it above.**
#
#
# 4. **The correlation between lead time and total stay is positive. That means that a longer stay will result in a longer lead time.**
#
# 5. **Adults, children and babies are correlated to each other. That means more the people more will be the adr.**
#
# 6. **is_repeated guest and previous_bookings_not_canceled has strong positive correlation. So, this means that repeated guests are not likely to cancel their bookings.**

# %% [markdown]
# # **5. Solution to Business Objective**

# %% [markdown]
# # What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# *   Analyze booking patterns and occupancy rates to identify peak seasons and optimize pricing strategies accordingly.
# *  Implement predictive models to forecast demand and adjust room rates dynamically for maximum revenue.
#
# *  Utilize guest data to personalize experiences, offer tailored promotions, and enhance customer loyalty programs.
# *  Continuously monitor and adapt strategies based on EDA findings and customer feedback to stay competitive in the market.
#
# *   Analyze competitor pricing and customer satisfaction data to identify areas where the hotel can differentiate itself and gain a competitive edge.
# *   Implement efficient processes for handling special requests to enhance guest satisfaction, potentially leading to positive reviews and repeat bookings.
#
# *   Create or enhance loyalty programs that incentivize repeat bookings and provide exclusive benefits to loyal customers, fostering customer retention.
# *   Develop and maintain active communication channels with customers, including email marketing and social media engagement, to keep them informed about promotions and special offers.
#
# *   Ensure that the hotel's website and booking process are mobile-friendly, as an increasing number of guests book accommodations via mobile devices, enhancing the user experience and conversion rates.
# *   Establish a feedback loop with front-line staff to gather insights from guest interactions, identifying potential issues and opportunities for improvement.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *   City hotels are the most preferred hotel type by the guests. So, we can say that City hotels are the busiest hotel in comparison to the resort hotel.
# *   The percentage of repeated guests is very low. Only 31.9% people had revisited the hotels. Rest 96.81% were new guests. So, retention rate is much low.
#
#
# *   Among different types of meals, BB (Bed & Breakfast) is the most preferred type of meal by the guests. So, guests love to opt for this meal type.
# *   Year 2016 had the highest bookings and Year 2015 had the lowest bookings and Year 2017 had the average number of bookings.
#
#
# *   The average ADR of city hotels is higher as compared to the resort hotels. So, it can be said that these City hotels are generating more revenue than the resort hotels.
# *  The total stay of guests is directly proportional to the adr. So, higher the days of stay, the higher will be ADR and revenue as well.
